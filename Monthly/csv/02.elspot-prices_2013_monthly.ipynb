# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('C:/Users/simhaj-local/Documents/GitHub/NordPool_Price/Monthly/xlsxFiles/02.elspot-prices_2013_monthly.xlsx', header=2)

# %%
df['DateAndTime'] = pd.date_range('1/1/2013', periods= 12, freq='M')

# %%
SE1 = df['SE1']
SE2 = df['SE2']
SE3 = df['SE3']
SE4 = df['SE4']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.xlabel('2012-Monthly-Price')
plt.ylabel('Amount')
plt.title('2012 Prices')


plt.plot(df.DateAndTime,SE1)
plt.plot(df.DateAndTime,SE2)
plt.plot(df.DateAndTime,SE3)
plt.plot(df.DateAndTime,SE4)

plt.legend(loc='upper left')
