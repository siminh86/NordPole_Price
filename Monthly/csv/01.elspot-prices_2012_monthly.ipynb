# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('C:/Users/simhaj-local/Documents/GitHub/NordPool_Price/Monthly/xlsxFiles/01.elspot-prices_2012_monthly..xlsx', header=2)

# %%
df.shape
# Out:
# (12, 17)

# %%
df
# Out:
#              SYS     SE1     SE2     SE3     SE4      FI     DK1     DK2  \
# 12 - Jan  328.95  328.61  328.61  337.96  338.49  343.49  327.42  333.15
# 12 - Feb  432.98  427.14  427.14  448.38  465.56  466.12  426.54  471.57
# 12 - Mar  259.40  251.37  257.74  257.74  263.99  324.37  280.00  284.23
# 12 - Apr  281.05  279.28  279.28  279.31  299.60  323.28  308.08  319.16
# 12 - May  256.12  263.44  263.44  269.60  287.31  299.75  324.10  326.64
# 12 - Jun  222.59  233.23  233.23  241.39  313.41  243.51  330.49  328.46
# 12 - Jul  117.91  115.04  115.04  115.04  166.64  117.67  219.33  243.63
# 12 - Aug  194.90  215.07  215.07  223.61  230.17  315.81  322.67  330.88
# 12 - Sep  215.34  247.59  247.59  250.24  254.80  348.32  317.37  321.20
# 12 - Oct  299.36  298.76  298.76  298.76  298.88  332.11  328.09  328.65
# 12 - Nov  294.34  290.32  290.32  290.32  290.60  317.92  300.40  310.37
# 12 - Dec  371.71  377.98  377.98  379.40  381.73  405.01  319.44  335.77
#
# ...

# %%
df['DateAndTime'] = pd.date_range('1/1/2012', periods= 12, freq='M')

# %%
df
# Out:
#              SYS     SE1     SE2     SE3     SE4      FI     DK1     DK2  \
# 12 - Jan  328.95  328.61  328.61  337.96  338.49  343.49  327.42  333.15
# 12 - Feb  432.98  427.14  427.14  448.38  465.56  466.12  426.54  471.57
# 12 - Mar  259.40  251.37  257.74  257.74  263.99  324.37  280.00  284.23
# 12 - Apr  281.05  279.28  279.28  279.31  299.60  323.28  308.08  319.16
# 12 - May  256.12  263.44  263.44  269.60  287.31  299.75  324.10  326.64
# 12 - Jun  222.59  233.23  233.23  241.39  313.41  243.51  330.49  328.46
# 12 - Jul  117.91  115.04  115.04  115.04  166.64  117.67  219.33  243.63
# 12 - Aug  194.90  215.07  215.07  223.61  230.17  315.81  322.67  330.88
# 12 - Sep  215.34  247.59  247.59  250.24  254.80  348.32  317.37  321.20
# 12 - Oct  299.36  298.76  298.76  298.76  298.88  332.11  328.09  328.65
# 12 - Nov  294.34  290.32  290.32  290.32  290.60  317.92  300.40  310.37
# 12 - Dec  371.71  377.98  377.98  379.40  381.73  405.01  319.44  335.77
#
# ...

# %%
SE1 = df['SE1']
SE2 = df['SE2']
SE3 = df['SE3']
SE4 = df['SE4']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 10), dpi=80, facecolor='w', edgecolor='k')

plt.xlabel('2012-Monthly-Price')
plt.ylabel('Amount')
plt.title('2012 Prices')


plt.plot(df.DateAndTime,SE1)
plt.plot(df.DateAndTime,SE2)
plt.plot(df.DateAndTime,SE3)
plt.plot(df.DateAndTime,SE4)

plt.legend(loc='upper left')
