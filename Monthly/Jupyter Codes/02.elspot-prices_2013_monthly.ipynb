# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(20, 10)})

# %%
df = pd.read_csv('C:/Users/simhaj-local/Documents/GitHub/NordPool_Price/Monthly/CSVFiles/02.elspot-prices_2013_monthly.csv',header = 2)

# %%
df['DateAndTime'] = pd.date_range('1/1/2013', periods=12, freq='M')

# %%
df.set_index('DateAndTime')
# Out:
#             Unnamed: 0     SYS     SE1     SE2     SE3     SE4      FI  \
# DateAndTime
# 2013-01-31    13 - Jan  357.07  357.32  357.32  361.49  364.16  358.81
# 2013-02-28    13 - Feb  338.01  335.92  335.92  335.92  336.99  335.92
# 2013-03-31    13 - Mar  374.40  371.31  371.31  371.31  371.31  375.91
# 2013-04-30    13 - Apr  386.66  369.70  369.70  369.70  370.68  369.76
# 2013-05-31    13 - May  315.98  315.89  315.89  315.89  316.73  320.08
# 2013-06-30    13 - Jun  290.00  296.35  296.35  296.35  298.35  334.80
# 2013-07-31    13 - Jul  292.62  296.14  296.14  296.14  302.74  320.62
# 2013-08-31    13 - Aug  307.95  351.24  351.24  351.24  351.32  378.18
# 2013-09-30    13 - Sep  333.46  387.19  387.19  396.64  398.62  414.55
# 2013-10-31    13 - Oct  335.14  361.64  361.64  369.21  369.45  401.84
# 2013-11-30    13 - Nov  325.89  328.13  328.13  331.25  355.66  337.75
# 2013-12-31    13 - Dec  292.61  291.95  291.95  294.60  304.84  319.35
#
# ...

# %%
df['SE1'].plot(linewidth=1.5, marker = '.', linestyle = '--')
df['SE2'].plot(linewidth=1.5, marker='o', linestyle='-')
df['SE3'].plot(linewidth=1.5, marker = 'v', linestyle='-')
df['SE4'].plot(linewidth=1.5, marker = 'd')
plt.title('2013 Monthly Price Change')
plt.xlabel('12 months in 2013')
plt.ylabel('Amount')
plt.legend()
