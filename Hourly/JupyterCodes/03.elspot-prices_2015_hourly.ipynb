# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(20, 10)})

# %%
df= pd.read_csv('C:/Users/simhaj-local/Documents/GitHub/NordPole_Price/Hourly/CSVFiles/03.elspot-prices_2015_hourly.csv', header=2)

# %%
df['DateAndTime'] = pd.date_range('1/1/2015', periods=8761, freq='H')

# %%
df['SE1'].plot(linewidth=1.5, marker = '.', linestyle = '--')
df['SE2'].plot(linewidth=1.5, marker='o', linestyle='-')
df['SE3'].plot(linewidth=1.5, marker = 'v', linestyle='-')
df['SE4'].plot(linewidth=1.5, marker = 'd')
plt.title('2015 Hourly Price Change')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend()

# %%
df['SE1'].plot(linewidth=1.5, marker = '.', linestyle = '--')

plt.title('2015 Hourly Price Change')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend()

# %%
df['SE2'].plot(linewidth=1.5, marker = '.', linestyle = '--')

plt.title('2015 Hourly Price Change')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend()

# %%
df['SE3'].plot(linewidth=1.5, marker = '.', linestyle = '--')

plt.title('2015 Hourly Price Change')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend()

# %%
df['SE4'].plot(linewidth=1.5, marker = '.', linestyle = '--')

plt.title('2015 Hourly Price Change')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend()
