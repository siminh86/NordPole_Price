# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install earthpy
# Out:
# Collecting earthpy
#   Using cached https://files.pythonhosted.org/packages/56/4a/81646f00a1378c1e4153b655d503843c9d225db2c9be7544d9ccbea4cc25/earthpy-0.7.4.tar.gz
# Collecting geopandas (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/51/10/9b2f2f6e35cc0e427f43faf59c56931709996ad2ffe4440fda2f5c53554f/geopandas-0.6.0-py2.py3-none-any.whl
# Requirement already satisfied: matplotlib>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from earthpy) (2.2.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\programdata\anaconda3\lib\site-packages (from earthpy) (1.15.1)
# Collecting rasterio (from earthpy)
#   Using cached https://files.pythonhosted.org/packages/1a/6d/ee8b15e0d45dd7e9e7f2559e37f91915a19155cf8403948ff2082903ee30/rasterio-1.1.0.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#     Complete output from command python setup.py egg_info:
#     INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#     ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in C:\Users\SIMHAJ~1\AppData\Local\Temp\pip-install-0c8uwfww\rasterio\
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import earthpy as et
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-2103e495d64e> in <module>()
#       6 from matplotlib.dates import DateFormatter
#       7 import seaborn as sns
# ----> 8 import earthpy as et
#
# ModuleNotFoundError: No module named 'earthpy'

# %%
# Date time conversion registration
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
# Get the data
data = et.data.get_data('C:/Users/simhaj-local/Documents/GitHub/NordPole_Price/Hourly/CSVFiles/06.elspot-prices_2018_hourly.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5ff50a3340c2> in <module>()
#       1 # Get the data
# ----> 2 data = et.data.get_data('C:/Users/simhaj-local/Documents/GitHub/NordPole_Price/Hourly/CSVFiles/06.elspot-prices_2018_hourly.csv')
#
# NameError: name 'et' is not defined

# %%
# Set working dir and import earthpy
os.chdir(os.path.join(et.io.HOME, 'earth-analytics'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3e4c67349b55> in <module>()
#       1 # Set working dir and import earthpy
# ----> 2 os.chdir(os.path.join(et.io.HOME, 'earth-analytics'))
#
# NameError: name 'et' is not defined

# %%
# Prettier plotting with seaborn
sns.set(font_scale=1.5, style="whitegrid")

# %%
# Open the data 
precip_file = "C:/Users/simhaj-local/Documents/GitHub/NordPole_Price/Hourly/CSVFiles/06.elspot-prices_2018_hourly.csv"
precip_boulder = pd.read_csv(precip_file,
                             na_values=[0],
                             parse_dates=['Hours'], 
                             index_col = 'Hours')
precip_boulder.head()
# Out:
#              Date     SYS     SE1     SE2     SE3     SE4      FI     DK1  \
# Hours
# 00 - 01  1/1/2018  258.67  258.86  258.86  258.86  258.86  258.86  214.33
# 01 - 02  1/1/2018  259.85  259.85  259.85  259.85  259.85  259.85  259.85
# 02 - 03  1/1/2018  256.50  256.60  256.60  256.60  256.60  256.60  256.60
# 03 - 04  1/1/2018  242.15  242.84  242.84  242.84  242.84  242.84  242.84
# 04 - 05  1/1/2018  242.54  243.23  243.23  243.23  243.23  243.23  243.23
#
#             DK2    Oslo  Kr.sand  Bergen   Molde  Tr.heim  Tromsø      EE  \
# Hours
# 00 - 01  258.86  258.86   258.86  258.86  258.86   258.86  258.86  258.86
# 01 - 02  259.85  259.85   259.85  259.85  259.85   259.85  259.85  259.85
# 02 - 03  256.60  256.60   256.60  256.60  256.60   256.60  256.60  256.60
# 03 - 04  242.84  242.84   242.84  242.84  242.84   242.84  242.84  242.84
# 04 - 05  243.23  243.23   243.23  243.23  243.23   243.23  243.23  243.23
#
#              LV      LT
# Hours
# 00 - 01  258.86  258.86
# 01 - 02  259.85  259.85
# 02 - 03  256.60  256.60
# 03 - 04  242.84  242.84
# 04 - 05  243.23  243.23

# %%
# Plot the data 
fig, ax = plt.subplots(figsize = (30,15))
ax.scatter(precip_boulder.index, 
           precip_boulder["SE1"], 
           color = 'purple')
ax.set(xlabel='Hours', ylabel='Sweden',
       title="Hourly price change 2018")
plt.show()

# %%
# Plot the data 
fig, ax = plt.subplots(figsize = (30,15))
ax.scatter(precip_boulder.index, 
           precip_boulder["Oslo"], 
           color = 'green')
ax.scatter(precip_boulder.index, 
           precip_boulder["Kr.sand"], 
           color = 'red')
ax.scatter(precip_boulder.index, 
           precip_boulder["Bergen"], 
           color = 'purple')
ax.scatter(precip_boulder.index, 
           precip_boulder["Molde"], 
           color = 'yellow')
ax.scatter(precip_boulder.index, 
           precip_boulder["Tr.heim"], 
           color = 'black')
ax.scatter(precip_boulder.index, 
           precip_boulder["Tromsø"], 
           color = 'blue')
ax.set(xlabel='Hours', ylabel='Norway',
       title="Hourly price change 2018")
plt.show()

# %%
# Plot the data 
fig, ax = plt.subplots(figsize = (30,15))
ax.scatter(precip_boulder.index, 
           precip_boulder["FI"], 
           color = 'blue')
ax.set(xlabel='Hours', ylabel='FI',
       title="Hourly price change 2018")
plt.show()

# %%
# Plot the data 
fig, ax = plt.subplots(figsize = (30,15))
ax.scatter(precip_boulder.index, 
           precip_boulder["DK1"], 
           color = 'blue')
ax.scatter(precip_boulder.index, 
           precip_boulder["DK2"], 
           color = 'red')
ax.set(xlabel='Hours', ylabel='Denmark',
       title="Hourly price change 2018")
plt.show()
